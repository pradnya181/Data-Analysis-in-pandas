# %% [markdown]
# # Univariate Analysis of categorical feature

# %% [raw]
# Data plotting approach with libraries
# 1.matplotlib
# 2.seaborn

# %%
import pandas as pd

# %%
A= pd.read_csv("C:/Users/I A T Laptop L.L.C/Desktop/JupyterN/50_Startups.csv")

# %% [markdown]
# # STATE variable is Balanced/Imbalanced?

# %%
A.STATE.hist() # histogram shows proportion of distribution of categorical data
# Out:
# <AxesSubplot:>

# %%
A.STATE.value_counts().plot(kind="barh")
# Out:
# <AxesSubplot:>

# %%
A.STATE.value_counts().plot(kind="pie")
# Out:
# <AxesSubplot:ylabel='STATE'>

# %% [markdown]
# Data is balanced because 3 of the states are having equally distribution of data

# %% [markdown]
# # RND --> Skewed | Not Skewed?

# %%
import seaborn as sb
sb.distplot(A.RND)
# Out:
# C:\Users\I A T Laptop L.L.C\anaconda3\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='RND', ylabel='Density'>

# %%
A.RND.mean()
# Out:
# 73721.61559999999

# %%
A.RND.median()
# Out:
# 73051.08

# %%
73721.61559999999-73051.08 # Difference of mean n median should be zero for non skewed data,that means here skew is present
# Out:
# 670.5355999999883

# %% [markdown]
# Mean & median values are not same thats why data is having skew / imbalance in data
